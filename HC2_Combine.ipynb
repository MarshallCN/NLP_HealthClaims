# %% [markdown]
# This notebook combined different attributes of HC from multiple data sources

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt  
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
PATH = "F:/colla/Documents/work/实习/RA/dataset"

# %% [markdown]
# # Combine Approved HC Data

# %%
FILE = "EFSA_Approved_Health_Claims.xlsx"
df_hc = pd.read_excel('{}/{}'.format(PATH,FILE), header=None)
df_hc.columns = ['hc']
df_hc['hc'] = [e.replace('</p>','').lower() for e in df_hc['hc']]
df_hc.head()
# Out:
#                                                   hc
# 0  ala contributes to the maintenance of normal b...
# 1  activated charcoal contributes to reducing exc...
# 2  barley grain fibre contributes to an increase ...
# 3  beta-glucans contribute to the maintenance of ...
# 4  betaine contributes to normal homocysteine met...

# %%
df_hc.shape
# Out:
# (261, 1)

# %%
FILE = "EU Health Claims - EN, DE, PL, FR.xlsx"
# data quality issue, has more NaN than EU Register file
df_hc_cat = pd.read_excel('{}/{}'.format(PATH,FILE))
df_hc_cat = df_hc_cat.iloc[1:,:2]
df_hc_cat.columns = ['nutrient','hc']
df_hc_cat['hc'] = [e.lower()+'.' for e in df_hc_cat['hc']]
df_hc_cat.head()
# Out:
#                                      nutrient  \
# 1                          Activated charcoal
# 2                          Alpha-cyclodextrin
# 3        Alpha-linolenic acid & linoleic acid
# 4                  Alpha-linolenic acid (ALA)
# 5  Arabinoxylan produced from wheat endosperm
#
#                                                   hc
# 1  activated charcoal contributes to reducing exc...
# 2  consumption of alpha-cyclodextrin as part of a...
# 3  essential fatty acids are needed for normal gr...
# 4  ala contributes to the maintenance of normal b...
# 5  consumption of arabinoxylan as part of a meal ...

# %%
df_hc_cat.shape
# Out:
# (260, 2)

# %%
FILE = "EU Register on Nutrition and Health Claims.xlsx"
df_hc_cond = pd.read_excel('{}/{}'.format(PATH,FILE))
df_hc_cond.columns = ['nutrient','hc','condition']
df_hc_cond['hc'] = [e.strip().lower()+'.' for e in df_hc_cond['hc']]
df_hc_cond['nutrient'] = df_hc_cond['nutrient'].str.lower()
df_hc_cond.head()
# Out:
#                                             nutrient  \
# 0  a combination of l-threonine, l-valine, l-leuc...
# 1                                 activated charcoal
# 2                                 alpha-cyclodextrin
# 3                         alpha-linolenic acid (ala)
# 4  alpha-linolenic acid (ala) & linoleic acid (la...
#
#                                                   hc  \
# 0  contributes to the reduction of the blood gluc...
# 1  activated charcoal contributes to reducing exc...
# 2  consumption of alpha-cyclodextrin as part of a...
# 3  ala contributes to the maintenance of normal b...
# 4  essential fatty acids are needed for normal gr...
#
#                                            condition
# 0                                                NaN
# 1  The claim may be used only for food which cont...
# 2  The claim may be used for food which contains ...
# 3  The claim may be used only for food which is a...
# 4  Information to the consumer that the beneficia...

# %%
df_hc_res = pd.merge(df_hc,df_hc_cond,how='left',on='hc')
df_hc_res.head()
# Out:
#                                                   hc  \
# 0  ala contributes to the maintenance of normal b...
# 1  activated charcoal contributes to reducing exc...
# 2  barley grain fibre contributes to an increase ...
# 3  beta-glucans contribute to the maintenance of ...
# 4  betaine contributes to normal homocysteine met...
#
#                      nutrient  \
# 0  alpha-linolenic acid (ala)
# 1                         NaN
# 2          barley grain fibre
# 3                beta-glucans
# 4                     betaine
#
#                                            condition
# 0  The claim may be used only for food which is a...
# 1                                                NaN
# 2  The claim may be used only for food which is h...
# 3  The claim may be used only for food which cont...
# 4  The claim may be used only for food which cont...

# %%
df_hc_res[pd.isnull(df_hc_res['nutrient'])]
# Out:
#                                                     hc nutrient condition
# 1    activated charcoal contributes to reducing exc...      NaN       NaN
# 35   consumption of foods/drinks containing &lt;nam...      NaN       NaN
# 36   in the case of d-tagatose and isomaltulose thi...      NaN       NaN
# 37   consumption of foods/drinks containing xx of s...      NaN       NaN
# 231  consumption of foods/drinks containing xx of a...      NaN       NaN
# 232  consumption of foods/drinks containing xx of a...      NaN       NaN
# 235  sugar beet fibre contributes to an&nbsp;increa...      NaN       NaN

# %%
FILE = "EFSA Claims with Keywords.xlsx"
df_hc_key = pd.read_excel('{}/{}'.format(PATH,FILE))
df_hc_key = df_hc_key.iloc[1:,[0,11]]
df_hc_key.columns = ['hc','keywords']
df_hc_key['hc'] = [e.lower() for e in df_hc_key['hc']]
# df_hc_key['nutrient'] = df_hc_cond['nutrient'].str.lower()
df_hc_key.head()
# Out:
#                                                   hc  \
# 1  activated charcoal contributes to reducing exc...
# 2  ala contributes to the maintenance of normal b...
# 3  barley beta-glucans has been shown to lower/re...
# 4  barley grain fibre contributes to an increase ...
# 5  beta-glucans contribute to the maintenance of ...
#
#                                             keywords
# 1                               charcoal, flatulence
# 2  ALA, alpha-linolenic acid, omega 3, blood, cho...
# 3  barley, beta-glucans, blood, cholesterol, hear...
# 4   barley, grain, fibre, fiber, faecal bulk, faeces
# 5                   beta-glucans, blood, cholesterol

# %%
df_hc_key.shape
# Out:
# (260, 2)

# %%
df_hc_res1 = pd.merge(df_hc_res, df_hc_key, how='left',on='hc')

# %%
df_hc_res1[pd.isnull(df_hc_res1['nutrient'])]
# Out:
#                                                     hc nutrient condition  \
# 1    activated charcoal contributes to reducing exc...      NaN       NaN
# 35   consumption of foods/drinks containing &lt;nam...      NaN       NaN
# 36   in the case of d-tagatose and isomaltulose thi...      NaN       NaN
# 37   consumption of foods/drinks containing xx of s...      NaN       NaN
# 231  consumption of foods/drinks containing xx of a...      NaN       NaN
# 232  consumption of foods/drinks containing xx of a...      NaN       NaN
# 235  sugar beet fibre contributes to an&nbsp;increa...      NaN       NaN
#
#                  keywords
# 1    charcoal, flatulence
# 35                    NaN
# 36                    NaN
# 37                    NaN
# 231                   NaN
# 232                   NaN
# 235                   NaN

# %%
# NaN value for neutirent
for i in df_hc_res[pd.isnull(df_hc_res['nutrient'])]['hc']:
    print(i)
    print()
# Out:
# consumption of foods/drinks containing xx of all used non-digestible carbohydrates; instead of sugars induces a lower blood glucose rise after their consumption compared to sugar-containing foods/drinks.
#
# consumption of foods/drinks containing xx of all used non-fermentable carbohydrates; instead of fermentable carbohydrates contributes to the maintenance of tooth mineralisation.
#
# sugar beet fibre contributes to an&nbsp;increase in&nbsp;faecal bulk.

# %%
# Manually populate neutirent value for few NaN value
df_hc_res.loc[df_hc_res[df_hc_res['hc'].str.contains("activated charcoal")].index,'nutrient']='activated charcoal'
df_hc_res.loc[df_hc_res[df_hc_res['hc'].str.contains("d-tagatose and isomaltulose")].index,'nutrient']='d-tagatose and isomaltulose'
df_hc_res.loc[df_hc_res[df_hc_res['hc'].str.contains("sugar replacer")].index,'nutrient']='sugar replacer'
df_hc_res.loc[df_hc_res[df_hc_res['hc'].str.contains("non-digestible carbohydrates")].index,'nutrient']='non-digestible carbohydrates'
df_hc_res.loc[df_hc_res[df_hc_res['hc'].str.contains("non-fermentable carbohydrates")].index,'nutrient']='non-fermentable carbohydrates'
df_hc_res.loc[df_hc_res[df_hc_res['hc'].str.contains("sugar beet fibre")].index,'nutrient']='sugar beet fibre'

# %%
df_hc_res[pd.isnull(df_hc_res['keywords'])]
# Out:
#      hc_ID                                                 hc  \
# 35      35  consumption of foods/drinks containing &lt;nam...
# 36      36  in the case of d-tagatose and isomaltulose thi...
# 37      37  consumption of foods/drinks containing xx of s...
# 129    129  replacing digestible starches with resistant s...
# 130    130  replacing saturated fats in the diet with unsa...
# 231    231  consumption of foods/drinks containing xx of a...
# 232    232  consumption of foods/drinks containing xx of a...
# 233    233  daily creatine consumption can enhance the eff...
# 235    235  sugar beet fibre contributes to an&nbsp;increa...
# 238    238  vitamin d helps to reduce the risk of falling ...
# 240    240  supplemental folic acid intake increases mater...
# 244    244  plant stanol esters have been shown to lower/r...
# 245    245  plant sterols and plant stanol esters have bee...
# 246    246  plant sterols have been shown to lower/reduce ...
# 247    247  sugar-free chewing gum helps neutralise plaque...
# 248    248  sugar-free chewing gum helps reduce tooth demi...
# 250    250  calcium is needed for normal growth and develo...
# 251    251  docosahexaenoic acid (dha) intake contributes ...
# 252    252  docosahexaenoic acid (dha) maternal intake con...
# 253    253  docosahexaenoic acid (dha) maternal intake con...
# 254    254  essential fatty acids are needed for normal gr...
# 258    258  protein is needed for normal growth and develo...
# 259    259  vitamin d contributes to the normal function o...
# 260    260  vitamin d is needed for normal growth and deve...
#
#                                               nutrient  \
# 35                                      sugar replacer
# 36                         d-tagatose and isomaltulose
# 37                                      sugar replacer
# 129                                   resistant starch
# 130                                         oleic acid
# 231                       non-digestible carbohydrates
# 232                      non-fermentable carbohydrates
# 233                                           creatine
# 235                                   sugar beet fibre
# 238                                          vitamin d
# 240                                         folic acid
# 244                                plant stanol esters
# 245                  plant sterols/plant stanol esters
# 246  plant sterols: sterols extracted from plants, ...
# 247                             sugar-free chewing gum
# 248                             sugar-free chewing gum
# 250                                            calcium
# 251                         docosahexaenoic acid (dha)
# 252                         docosahexaenoic acid (dha)
# 253                         docosahexaenoic acid (dha)
# 254  alpha-linolenic acid (ala) & linoleic acid (la...
# 258                                            protein
# 259                                          vitamin d
# 260                                          vitamin d
#
#                                              condition keywords  \
# 35                                                 NaN      NaN
# 36                                                 NaN      NaN
# 37                                                 NaN      NaN
# 129  The claim may be used only for food in which d...      NaN
# 130  The claim may be used only for food which is h...      NaN
# 231                                                NaN      NaN
# 232                                                NaN      NaN
# 233  Information shall be provided to the consumer ...      NaN
# 235                                                NaN      NaN
# 238  The claim may be used only for food supplement...      NaN
# 240  The claim may be used only for food supplement...      NaN
# 244  Information to the consumer that the beneficia...      NaN
# 245  Information to the consumer that the beneficia...      NaN
# 246  Information to the consumer that the beneficia...      NaN
# 247  Information shall be given to the consumer tha...      NaN
# 248  Information shall be given to the consumer tha...      NaN
# 250  The claim can be used only for food which is a...      NaN
# 251  Information shall be given to the consumer tha...      NaN
# 252  Information shall be given to pregnant and lac...      NaN
# 253  Information shall be given to pregnant and lac...      NaN
# 254  Information to the consumer that the beneficia...      NaN
# 258  The claim can be used only for food which is a...      NaN
# 259  The claim may be used only for food which is a...      NaN
# 260  The claim can be used only for food which is a...      NaN
#
#                                                    pos  \
# 35   [NN, IN, NNS, VBG, CC, NN, :, NN, IN, NN, NN, ...
# 36   [IN, DT, NN, IN, JJ, CC, VB, DT, MD, VB, ``, J...
# 37   [NN, IN, NNS, VBG, NN, IN, NN, NN, :, RB, IN, ...
# 129  [VBG, JJ, NNS, IN, JJ, NN, IN, DT, NN, VBZ, TO...
# 130  [VBG, VBN, NNS, IN, DT, NN, IN, JJ, NNS, VBZ, ...
# 231  [NN, IN, NNS, VBG, NN, IN, DT, VBN, JJ, NNS, :...
# 232  [NN, IN, NNS, VBG, NN, IN, DT, VBN, JJ, NNS, :...
# 233  [JJ, NN, NN, MD, VB, DT, NN, IN, NN, NN, IN, N...
# 235  [NN, NN, NN, VBZ, TO, DT, CC, NN, :, NN, IN, C...
# 238  [NN, NN, VBZ, TO, VB, DT, NN, IN, VBG, VBN, IN...
# 240  [JJ, JJ, NNS, VBP, NNS, JJ, NN, NN, ., JJ, JJ,...
# 244  [NN, NN, NNS, VBP, VBN, VBN, TO, VB, NN, NN, ....
# 245  [NN, NNS, CC, NN, NN, NNS, VBP, VBN, VBN, TO, ...
# 246  [NN, NNS, VBP, VBN, VBN, TO, VB, NN, NN, ., JJ...
# 247  [JJ, VBG, NN, VBZ, RB, JJ, NNS, ., NN, NNS, VB...
# 248  [JJ, VBG, NN, VBZ, VB, DT, NN, ., DT, NN, VBZ,...
# 250  [NN, VBZ, VBN, IN, JJ, NN, CC, NN, IN, NN, IN,...
# 251  [NN, NN, (, NN, ), NN, NNS, TO, DT, JJ, JJ, NN...
# 252  [NN, NN, (, NN, ), JJ, NN, NNS, TO, DT, JJ, NN...
# 253  [NN, NN, (, NN, ), JJ, NN, NNS, TO, DT, JJ, NN...
# 254  [JJ, JJ, NNS, VBP, VBN, IN, JJ, NN, CC, NN, IN...
# 258  [NN, VBZ, VBN, IN, JJ, NN, CC, NN, IN, NN, IN,...
# 259  [NN, NN, VBZ, TO, DT, JJ, NN, IN, DT, NN, NN, ...
# 260  [NN, NN, VBZ, VBN, IN, JJ, NN, CC, NN, IN, NN,...
#
#                                              hc_tagged
# 35   [(consumption, NN), (of, IN), (foods/drinks, N...
# 36   [(in, IN), (the, DT), (case, NN), (of, IN), (d...
# 37   [(consumption, NN), (of, IN), (foods/drinks, N...
# 129  [(replacing, VBG), (digestible, JJ), (starches...
# 130  [(replacing, VBG), (saturated, VBN), (fats, NN...
# 231  [(consumption, NN), (of, IN), (foods/drinks, N...
# 232  [(consumption, NN), (of, IN), (foods/drinks, N...
# 233  [(daily, JJ), (creatine, NN), (consumption, NN...
# 235  [(sugar, NN), (beet, NN), (fibre, NN), (contri...
# 238  [(vitamin, NN), (d, NN), (helps, VBZ), (to, TO...
# 240  [(supplemental, JJ), (folic, JJ), (acid, NNS),...
# 244  [(plant, NN), (stanol, NN), (esters, NNS), (ha...
# 245  [(plant, NN), (sterols, NNS), (and, CC), (plan...
# 246  [(plant, NN), (sterols, NNS), (have, VBP), (be...
# 247  [(sugar-free, JJ), (chewing, VBG), (gum, NN), ...
# 248  [(sugar-free, JJ), (chewing, VBG), (gum, NN), ...
# 250  [(calcium, NN), (is, VBZ), (needed, VBN), (for...
# 251  [(docosahexaenoic, NN), (acid, NN), ((, (), (d...
# 252  [(docosahexaenoic, NN), (acid, NN), ((, (), (d...
# 253  [(docosahexaenoic, NN), (acid, NN), ((, (), (d...
# 254  [(essential, JJ), (fatty, JJ), (acids, NNS), (...
# 258  [(protein, NN), (is, VBZ), (needed, VBN), (for...
# 259  [(vitamin, NN), (d, NN), (contributes, VBZ), (...
# 260  [(vitamin, NN), (d, NN), (is, VBZ), (needed, V...

# %%
df_hc_res['hc_ID'] = df_hc_res.index
df_hc_res = df_hc_res[['hc_ID']+list(df_hc_res.columns[:-1])]

# %% [markdown]
# # Adding Pos-tagging

# %%
df_hc_res.loc[:,'pos'] = [[i[1] for i in nltk.pos_tag(word_tokenize(s))] for s in df_hc_res.hc]
df_hc_res.loc[:,'hc_tagged'] = [nltk.pos_tag(word_tokenize(s)) for s in df_hc_res.hc]
df_hc_res.head()
# Out:
#    hc_ID                                                 hc  \
# 0      0  ala contributes to the maintenance of normal b...
# 1      1  activated charcoal contributes to reducing exc...
# 2      2  barley grain fibre contributes to an increase ...
# 3      3  beta-glucans contribute to the maintenance of ...
# 4      4  betaine contributes to normal homocysteine met...
#
#                      nutrient  \
# 0  alpha-linolenic acid (ala)
# 1                         NaN
# 2          barley grain fibre
# 3                beta-glucans
# 4                     betaine
#
#                                            condition  \
# 0  The claim may be used only for food which is a...
# 1                                                NaN
# 2  The claim may be used only for food which is h...
# 3  The claim may be used only for food which cont...
# 4  The claim may be used only for food which cont...
#
#                                             keywords  \
# 0  ALA, alpha-linolenic acid, omega 3, blood, cho...
# 1                               charcoal, flatulence
# 2   barley, grain, fibre, fiber, faecal bulk, faeces
# 3                   beta-glucans, blood, cholesterol
# 4                  betaine, homocysteine, metabolism
#
#                                              pos  \
# 0  [NN, NNS, TO, DT, NN, IN, JJ, NN, NN, NNS, .]
# 1    [VBN, NN, NNS, TO, VBG, JJ, NN, IN, VBG, .]
# 2   [NN, NN, NN, VBZ, TO, DT, NN, IN, JJ, NN, .]
# 3  [NNS, NN, TO, DT, NN, IN, JJ, NN, NN, NNS, .]
# 4                   [NN, VBZ, TO, JJ, JJ, NN, .]
#
#                                            hc_tagged
# 0  [(ala, NN), (contributes, NNS), (to, TO), (the...
# 1  [(activated, VBN), (charcoal, NN), (contribute...
# 2  [(barley, NN), (grain, NN), (fibre, NN), (cont...
# 3  [(beta-glucans, NNS), (contribute, NN), (to, T...
# 4  [(betaine, NN), (contributes, VBZ), (to, TO), ...

# %%
def drawTree(tagged):
    grammar = r"""
      NP: {<DT|JJ|NN.*>+}          # Chunk sequences of DT, JJ, NN
      PP: {<IN><NP>}               # Chunk prepositions followed by NP
      VP: {<VB.*><NP|PP|CLAUSE>+$} # Chunk verbs and their arguments
      CLAUSE: {<NP><VP>}           # Chunk NP, VP
      """
    cp = nltk.RegexpParser(grammar)
    chunked = cp.parse(tagged)
    chunked.draw()

# %% [markdown]
# # Export Combine Approved HC data

# %%
import pickle
# with open('df_hc_res.pickle', 'wb') as handle:
#     pickle.dump(df_hc_res1, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('df_hc_res.pickle', 'rb') as handle:
    df_hc_res = pickle.load(handle)

# %%
df_hc_res[df_hc_res['nutrient']=='live yoghurt cultures']['hc'][83]
# Out:
# 'live cultures in yoghurt or fermented milk improve lactose digestion of the product in individuals who have difficulty digesting lactose.'

# %% [markdown]
# # Extract benefit and phrase

# %%
df_hc_res.loc[:,'benefit'] = [s.split( ' to ')[1].replace('.','').strip() if ' to ' in s else '' for s in df_hc_res.hc]
df_hc_res.loc[:,'phrase'] = [s.split( ' to ')[0].split(' ')[-1].strip()+' to' if ' to ' in s else '' for s in df_hc_res.hc]

# %%
for i in df_hc_res[df_hc_res.benefit==''].index:
    hc = df_hc_res.loc[i, 'hc']
    phrases = ['needed for', 'has a role in','enhance','increases','improve','improves','helps']
    for p in phrases:
        if f' {p} ' in hc:
            df_hc_res.loc[i, 'phrase'] = p
            df_hc_res.loc[i, 'benefit'] = hc.split(f' {p} ')[1].replace('.','').strip()

# %%
df_hc_res[df_hc_res.benefit==''].hc.values
# Out:
# array(['in the case of d-tagatose and isomaltulose this should read "other sugars".',
#        'sugar-free chewing gum with carbamide neutralises plaque acids more effectively than sugar-free chewing gums without carbamide.'],
#       dtype=object)

# %%
df_hc_res
# Out:
#      hc_ID                                                 hc  \
# 0        0  ala contributes to the maintenance of normal b...
# 1        1  activated charcoal contributes to reducing exc...
# 2        2  barley grain fibre contributes to an increase ...
# 3        3  beta-glucans contribute to the maintenance of ...
# 4        4  betaine contributes to normal homocysteine met...
# 5        5  biotin contributes to normal energy-yielding m...
# 6        6  biotin contributes to normal functioning of th...
# 7        7  biotin contributes to normal macronutrient met...
# 8        8  biotin contributes to normal psychological fun...
# 9        9  biotin contributes to the maintenance of norma...
# 10      10  biotin contributes to the maintenance of norma...
# 11      11  biotin contributes to the maintenance of norma...
# 12      12      calcium contributes to normal blood clotting.
# 13      13  calcium contributes to normal energy-yielding ...
# 14      14     calcium contributes to normal muscle function.
# 15      15   calcium contributes to normal neurotransmission.
# 16      16  calcium contributes to the normal function of ...
# 17      17  calcium has a role in the process of cell divi...
# 18      18  calcium is needed for the maintenance of norma...
# 19      19  calcium is needed for the maintenance of norma...
# 20      20  carbohydrate-electrolyte solutions contribute ...
# 21      21  carbohydrate-electrolyte solutions enhance the...
# 22      22  carbohydrates contribute to the maintenance of...
# 23      23  chitosan contributes to the maintenance of nor...
# 24      24  chloride contributes to normal digestion by pr...
# 25      25  choline contributes to normal homocysteine met...
# 26      26    choline contributes to normal lipid metabolism.
# 27      27  choline contributes to the maintenance of norm...
# 28      28  chromium contributes to normal macronutrient m...
# 29      29  chromium contributes to the maintenance of nor...
# ..     ...                                                ...
# 231    231  consumption of foods/drinks containing xx of a...
# 232    232  consumption of foods/drinks containing xx of a...
# 233    233  daily creatine consumption can enhance the eff...
# 234    234  lactitol contributes to normal bowel function ...
# 235    235  sugar beet fibre contributes to an&nbsp;increa...
# 236    236  calcium and vitamin d help to reduce the loss ...
# 237    237  calcium helps to reduce the loss of bone miner...
# 238    238  vitamin d helps to reduce the risk of falling ...
# 239    239  replacing saturated fats with unsaturated fats...
# 240    240  supplemental folic acid intake increases mater...
# 241    241  barley beta-glucans has been shown to lower/re...
# 242    242  chewing gum sweetened with 100% xylitol has be...
# 243    243  oat beta-glucan has been shown to lower/reduce...
# 244    244  plant stanol esters have been shown to lower/r...
# 245    245  plant sterols and plant stanol esters have bee...
# 246    246  plant sterols have been shown to lower/reduce ...
# 247    247  sugar-free chewing gum helps neutralise plaque...
# 248    248  sugar-free chewing gum helps reduce tooth demi...
# 249    249  calcium and vitamin d are needed for normal gr...
# 250    250  calcium is needed for normal growth and develo...
# 251    251  docosahexaenoic acid (dha) intake contributes ...
# 252    252  docosahexaenoic acid (dha) maternal intake con...
# 253    253  docosahexaenoic acid (dha) maternal intake con...
# 254    254  essential fatty acids are needed for normal gr...
# 255    255  iodine contributes to the normal growth of chi...
# 256    256  iron contributes to normal cognitive developme...
# 257    257  phosphorus is needed for the normal growth and...
# 258    258  protein is needed for normal growth and develo...
# 259    259  vitamin d contributes to the normal function o...
# 260    260  vitamin d is needed for normal growth and deve...
#
#                                               nutrient  \
# 0                           alpha-linolenic acid (ala)
# 1                                   activated charcoal
# 2                                   barley grain fibre
# 3                                         beta-glucans
# 4                                              betaine
# 5                                               biotin
# 6                                               biotin
# 7                                               biotin
# 8                                               biotin
# 9                                               biotin
# 10                                              biotin
# 11                                              biotin
# 12                                             calcium
# 13                                             calcium
# 14                                             calcium
# 15                                             calcium
# 16                                             calcium
# 17                                             calcium
# 18                                             calcium
# 19                                             calcium
# 20                  carbohydrate-electrolyte solutions
# 21                  carbohydrate-electrolyte solutions
# 22                                       carbohydrates
# 23                                            chitosan
# 24                                            chloride
# 25                                             choline
# 26                                             choline
# 27                                             choline
# 28                                            chromium
# 29                                            chromium
# ..                                                 ...
# 231                       non-digestible carbohydrates
# 232                      non-fermentable carbohydrates
# 233                                           creatine
# 234                                           lactitol
# 235                                   sugar beet fibre
# 236                              calcium and vitamin d
# 237                                            calcium
# 238                                          vitamin d
# 239  monounsaturated and/or polyunsaturated fatty a...
# 240                                         folic acid
# 241                                barley beta-glucans
# 242            chewing gum sweetened with 100% xylitol
# 243                                    oat beta-glucan
# 244                                plant stanol esters
# 245                  plant sterols/plant stanol esters
# 246  plant sterols: sterols extracted from plants, ...
# 247                             sugar-free chewing gum
# 248                             sugar-free chewing gum
# 249                              calcium and vitamin d
# 250                                            calcium
# 251                         docosahexaenoic acid (dha)
# 252                         docosahexaenoic acid (dha)
# 253                         docosahexaenoic acid (dha)
# 254  alpha-linolenic acid (ala) & linoleic acid (la...
# 255                                             iodine
# 256                                               iron
# 257                                         phosphorus
# 258                                            protein
# 259                                          vitamin d
# 260                                          vitamin d
#
#                                              condition  \
# 0    The claim may be used only for food which is a...
# 1                                                  NaN
# 2    The claim may be used only for food which is h...
# 3    The claim may be used only for food which cont...
# 4    The claim may be used only for food which cont...
# 5    The claim may be used only for food which is a...
# 6    The claim may be used only for food which is a...
# 7    The claim may be used only for food which is a...
# 8    The claim may be used only for food which is a...
# 9    The claim may be used only for food which is a...
# 10   The claim may be used only for food which is a...
# 11   The claim may be used only for food which is a...
# 12   The claim may be used only for food which is a...
# 13   The claim may be used only for food which is a...
# 14   The claim may be used only for food which is a...
# 15   The claim may be used only for food which is a...
# 16   The claim may be used only for food which is a...
# 17   The claim may be used only for food which is a...
# 18   The claim may be used only for food which is a...
# 19   The claim may be used only for food which is a...
# 20   In order to bear the claim carbohydrate-electr...
# 21   In order to bear the claim carbohydrate-electr...
# 22   In order to bear the claim, information shall ...
# 23   The claim may be used only for food which prov...
# 24   The claim may be used only for food which is a...
# 25   The claim may be used only for food which cont...
# 26   The claim may be used only for food which cont...
# 27   The claim may be used only for food which cont...
# 28   The claim may be used only for food which is a...
# 29   The claim may be used only for food which is a...
# ..                                                 ...
# 231                                                NaN
# 232                                                NaN
# 233  Information shall be provided to the consumer ...
# 234  The claim may be used only for food supplement...
# 235                                                NaN
# 236  The claim may be used only for food supplement...
# 237  The claim may be used only for food which prov...
# 238  The claim may be used only for food supplement...
# 239  The claim may be used only for food which is h...
# 240  The claim may be used only for food supplement...
# 241  Information shall be given to the consumer tha...
# 242  Information to the consumer that the beneficia...
# 243  Information shall be given to the consumer tha...
# 244  Information to the consumer that the beneficia...
# 245  Information to the consumer that the beneficia...
# 246  Information to the consumer that the beneficia...
# 247  Information shall be given to the consumer tha...
# 248  Information shall be given to the consumer tha...
# 249  The claim can be used only for food which is a...
# 250  The claim can be used only for food which is a...
# 251  Information shall be given to the consumer tha...
# 252  Information shall be given to pregnant and lac...
# 253  Information shall be given to pregnant and lac...
# 254  Information to the consumer that the beneficia...
# 255  The claim can be used only for food which is a...
# 256  The claim can be used only for food which is a...
# 257  The claim can be used only for food which is a...
# 258  The claim can be used only for food which is a...
# 259  The claim may be used only for food which is a...
# 260  The claim can be used only for food which is a...
#
#                                               keywords  \
# 0    ALA, alpha-linolenic acid, omega 3, blood, cho...
# 1                                 charcoal, flatulence
# 2     barley, grain, fibre, fiber, faecal bulk, faeces
# 3                     beta-glucans, blood, cholesterol
# 4                    betaine, homocysteine, metabolism
# 5               biotin, vitamin B7, energy, metabolism
# 6                   biotin, vitamin B7, nervous system
# 7                       biotin, vitamin B7, metabolism
# 8        biotin, vitamin B7, psychological, psychology
# 9                             biotin, vitamin B7, hair
# 10                biotin, vitamin B7, mucous membranes
# 11                            biotin, vitamin B7, skin
# 12                            calcium, blood, clotting
# 13                         calcium, energy, metabolism
# 14                                     calcium, muscle
# 15                          calcium, neurotransmission
# 16              calcium, digestive, enzymes, digestion
# 17   calcium, cell division, specialisation, specia...
# 18                                      calcium, bones
# 19                                      calcium, teeth
# 20   carbohydrate, electrolyte, solutions, enduranc...
# 21   carbohydrate, electrolyte, solutions, absorpti...
# 22                                carbohydrates, brain
# 23                        chitosan, blood, cholesterol
# 24     chloride, digestion, hydrochloric acid, stomach
# 25                   choline, homocysteine, metabolism
# 26                          choline, lipid, metabolism
# 27                                      choline, liver
# 28                 chromium, macronutrient, metabolism
# 29                     chromium, blood, glucose, sugar
# ..                                                 ...
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                             lactitol, bowel, stool
# 235                                                NaN
# 236  calcium, vitamin D, bone, mineral, women, meno...
# 237  calcium, bone, mineral, women, menopause, oste...
# 238                                                NaN
# 239  saturated, fat, saturates, unsaturated, blood,...
# 240                                                NaN
# 241  barley, beta-glucans, blood, cholesterol, hear...
# 242  chewing gum, xylitol, plaque, caries, children...
# 243  oat, beta-glucan, blood, cholesterol, coronary...
# 244                                                NaN
# 245                                                NaN
# 246                                                NaN
# 247                                                NaN
# 248                                                NaN
# 249                 calcium, vitamin D, bone, children
# 250                                                NaN
# 251                                                NaN
# 252                                                NaN
# 253                                                NaN
# 254                                                NaN
# 255                           iodine, growth, children
# 256               iron, cognitive, cognition, children
# 257                         phosphorus, bone, children
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
#
#                                                    pos  \
# 0        [NN, NNS, TO, DT, NN, IN, JJ, NN, NN, NNS, .]
# 1          [VBN, NN, NNS, TO, VBG, JJ, NN, IN, VBG, .]
# 2         [NN, NN, NN, VBZ, TO, DT, NN, IN, JJ, NN, .]
# 3        [NNS, NN, TO, DT, NN, IN, JJ, NN, NN, NNS, .]
# 4                         [NN, VBZ, TO, JJ, JJ, NN, .]
# 5                         [NN, VBZ, TO, JJ, JJ, NN, .]
# 6             [NN, VBZ, TO, JJ, NN, IN, DT, JJ, NN, .]
# 7                         [NN, VBZ, TO, JJ, JJ, NN, .]
# 8                         [NN, VBZ, TO, JJ, JJ, NN, .]
# 9                 [NN, NNS, TO, DT, NN, IN, JJ, NN, .]
# 10           [NN, NNS, TO, DT, NN, IN, JJ, JJ, NNS, .]
# 11                [NN, NNS, TO, DT, NN, IN, JJ, NN, .]
# 12                        [NN, VBZ, TO, JJ, NN, NN, .]
# 13                        [NN, VBZ, TO, JJ, JJ, NN, .]
# 14                        [NN, VBZ, TO, JJ, NN, NN, .]
# 15                            [NN, VBZ, TO, JJ, NN, .]
# 16           [NN, VBZ, TO, DT, JJ, NN, IN, JJ, NNS, .]
# 17   [NN, VBZ, DT, NN, IN, DT, NN, IN, NN, NN, CC, ...
# 18          [NN, VBZ, VBN, IN, DT, NN, IN, JJ, NNS, .]
# 19          [NN, VBZ, VBN, IN, DT, NN, IN, JJ, NNS, .]
# 20   [JJ, NNS, VBP, TO, DT, NN, IN, NN, NN, IN, JJ,...
# 21        [JJ, NNS, VB, DT, NN, IN, NN, IN, JJ, NN, .]
# 22           [NNS, VBP, TO, DT, NN, IN, JJ, NN, NN, .]
# 23       [JJ, NNS, TO, DT, NN, IN, JJ, NN, NN, NNS, .]
# 24   [NN, VBZ, TO, JJ, NN, IN, NN, IN, JJ, NN, IN, ...
# 25                        [NN, VBZ, TO, JJ, JJ, NN, .]
# 26                        [NN, VBZ, TO, JJ, JJ, NN, .]
# 27            [NN, NNS, TO, DT, NN, IN, JJ, JJ, NN, .]
# 28                        [NN, VBZ, TO, JJ, JJ, NN, .]
# 29       [NN, VBZ, TO, DT, NN, IN, JJ, NN, NN, NNS, .]
# ..                                                 ...
# 231  [NN, IN, NNS, VBG, NN, IN, DT, VBN, JJ, NNS, :...
# 232  [NN, IN, NNS, VBG, NN, IN, DT, VBN, JJ, NNS, :...
# 233  [JJ, NN, NN, MD, VB, DT, NN, IN, NN, NN, IN, N...
# 234      [NN, NNS, TO, JJ, NN, NN, IN, VBG, JJ, NN, .]
# 235  [NN, NN, NN, VBZ, TO, DT, CC, NN, :, NN, IN, C...
# 236  [NN, CC, NN, NN, NN, TO, VB, DT, NN, IN, JJ, N...
# 237  [NN, VBZ, TO, VB, DT, NN, IN, JJ, NN, IN, JJ, ...
# 238  [NN, NN, VBZ, TO, VB, DT, NN, IN, VBG, VBN, IN...
# 239  [VBG, VBD, NNS, IN, JJ, NNS, IN, DT, NN, VBZ, ...
# 240  [JJ, JJ, NNS, VBP, NNS, JJ, NN, NN, ., JJ, JJ,...
# 241  [NN, NNS, VBZ, VBN, VBN, TO, VB, NN, NN, ., JJ...
# 242  [VBG, NN, VBD, IN, CD, NN, NN, VBZ, VBN, VBN, ...
# 243  [NN, NN, VBZ, VBN, VBN, TO, VB, NN, NN, ., JJ,...
# 244  [NN, NN, NNS, VBP, VBN, VBN, TO, VB, NN, NN, ....
# 245  [NN, NNS, CC, NN, NN, NNS, VBP, VBN, VBN, TO, ...
# 246  [NN, NNS, VBP, VBN, VBN, TO, VB, NN, NN, ., JJ...
# 247  [JJ, VBG, NN, VBZ, RB, JJ, NNS, ., NN, NNS, VB...
# 248  [JJ, VBG, NN, VBZ, VB, DT, NN, ., DT, NN, VBZ,...
# 249  [NN, CC, NN, NN, VBP, VBN, IN, JJ, NN, CC, NN,...
# 250  [NN, VBZ, VBN, IN, JJ, NN, CC, NN, IN, NN, IN,...
# 251  [NN, NN, (, NN, ), NN, NNS, TO, DT, JJ, JJ, NN...
# 252  [NN, NN, (, NN, ), JJ, NN, NNS, TO, DT, JJ, NN...
# 253  [NN, NN, (, NN, ), JJ, NN, NNS, TO, DT, JJ, NN...
# 254  [JJ, JJ, NNS, VBP, VBN, IN, JJ, NN, CC, NN, IN...
# 255              [NN, NNS, TO, DT, JJ, NN, IN, NNS, .]
# 256              [NN, NNS, TO, JJ, JJ, NN, IN, NNS, .]
# 257  [NN, VBZ, VBN, IN, DT, JJ, NN, CC, NN, IN, NN,...
# 258  [NN, VBZ, VBN, IN, JJ, NN, CC, NN, IN, NN, IN,...
# 259  [NN, NN, VBZ, TO, DT, JJ, NN, IN, DT, NN, NN, ...
# 260  [NN, NN, VBZ, VBN, IN, JJ, NN, CC, NN, IN, NN,...
#
#                                              hc_tagged  \
# 0    [(ala, NN), (contributes, NNS), (to, TO), (the...
# 1    [(activated, VBN), (charcoal, NN), (contribute...
# 2    [(barley, NN), (grain, NN), (fibre, NN), (cont...
# 3    [(beta-glucans, NNS), (contribute, NN), (to, T...
# 4    [(betaine, NN), (contributes, VBZ), (to, TO), ...
# 5    [(biotin, NN), (contributes, VBZ), (to, TO), (...
# 6    [(biotin, NN), (contributes, VBZ), (to, TO), (...
# 7    [(biotin, NN), (contributes, VBZ), (to, TO), (...
# 8    [(biotin, NN), (contributes, VBZ), (to, TO), (...
# 9    [(biotin, NN), (contributes, NNS), (to, TO), (...
# 10   [(biotin, NN), (contributes, NNS), (to, TO), (...
# 11   [(biotin, NN), (contributes, NNS), (to, TO), (...
# 12   [(calcium, NN), (contributes, VBZ), (to, TO), ...
# 13   [(calcium, NN), (contributes, VBZ), (to, TO), ...
# 14   [(calcium, NN), (contributes, VBZ), (to, TO), ...
# 15   [(calcium, NN), (contributes, VBZ), (to, TO), ...
# 16   [(calcium, NN), (contributes, VBZ), (to, TO), ...
# 17   [(calcium, NN), (has, VBZ), (a, DT), (role, NN...
# 18   [(calcium, NN), (is, VBZ), (needed, VBN), (for...
# 19   [(calcium, NN), (is, VBZ), (needed, VBN), (for...
# 20   [(carbohydrate-electrolyte, JJ), (solutions, N...
# 21   [(carbohydrate-electrolyte, JJ), (solutions, N...
# 22   [(carbohydrates, NNS), (contribute, VBP), (to,...
# 23   [(chitosan, JJ), (contributes, NNS), (to, TO),...
# 24   [(chloride, NN), (contributes, VBZ), (to, TO),...
# 25   [(choline, NN), (contributes, VBZ), (to, TO), ...
# 26   [(choline, NN), (contributes, VBZ), (to, TO), ...
# 27   [(choline, NN), (contributes, NNS), (to, TO), ...
# 28   [(chromium, NN), (contributes, VBZ), (to, TO),...
# 29   [(chromium, NN), (contributes, VBZ), (to, TO),...
# ..                                                 ...
# 231  [(consumption, NN), (of, IN), (foods/drinks, N...
# 232  [(consumption, NN), (of, IN), (foods/drinks, N...
# 233  [(daily, JJ), (creatine, NN), (consumption, NN...
# 234  [(lactitol, NN), (contributes, NNS), (to, TO),...
# 235  [(sugar, NN), (beet, NN), (fibre, NN), (contri...
# 236  [(calcium, NN), (and, CC), (vitamin, NN), (d, ...
# 237  [(calcium, NN), (helps, VBZ), (to, TO), (reduc...
# 238  [(vitamin, NN), (d, NN), (helps, VBZ), (to, TO...
# 239  [(replacing, VBG), (saturated, VBD), (fats, NN...
# 240  [(supplemental, JJ), (folic, JJ), (acid, NNS),...
# 241  [(barley, NN), (beta-glucans, NNS), (has, VBZ)...
# 242  [(chewing, VBG), (gum, NN), (sweetened, VBD), ...
# 243  [(oat, NN), (beta-glucan, NN), (has, VBZ), (be...
# 244  [(plant, NN), (stanol, NN), (esters, NNS), (ha...
# 245  [(plant, NN), (sterols, NNS), (and, CC), (plan...
# 246  [(plant, NN), (sterols, NNS), (have, VBP), (be...
# 247  [(sugar-free, JJ), (chewing, VBG), (gum, NN), ...
# 248  [(sugar-free, JJ), (chewing, VBG), (gum, NN), ...
# 249  [(calcium, NN), (and, CC), (vitamin, NN), (d, ...
# 250  [(calcium, NN), (is, VBZ), (needed, VBN), (for...
# 251  [(docosahexaenoic, NN), (acid, NN), ((, (), (d...
# 252  [(docosahexaenoic, NN), (acid, NN), ((, (), (d...
# 253  [(docosahexaenoic, NN), (acid, NN), ((, (), (d...
# 254  [(essential, JJ), (fatty, JJ), (acids, NNS), (...
# 255  [(iodine, NN), (contributes, NNS), (to, TO), (...
# 256  [(iron, NN), (contributes, NNS), (to, TO), (no...
# 257  [(phosphorus, NN), (is, VBZ), (needed, VBN), (...
# 258  [(protein, NN), (is, VBZ), (needed, VBN), (for...
# 259  [(vitamin, NN), (d, NN), (contributes, VBZ), (...
# 260  [(vitamin, NN), (d, NN), (is, VBZ), (needed, V...
#
#                                                benefit          phrase
# 0    the maintenance of normal blood cholesterol le...  contributes to
# 1           reducing excessive flatulence after eating  contributes to
# 2                           an increase in faecal bulk  contributes to
# 3    the maintenance of normal blood cholesterol le...   contribute to
# 4                       normal homocysteine metabolism  contributes to
# 5                    normal energy-yielding metabolism  contributes to
# 6             normal functioning of the nervous system  contributes to
# 7                      normal macronutrient metabolism  contributes to
# 8                        normal psychological function  contributes to
# 9                       the maintenance of normal hair  contributes to
# 10          the maintenance of normal mucous membranes  contributes to
# 11                      the maintenance of normal skin  contributes to
# 12                               normal blood clotting  contributes to
# 13                   normal energy-yielding metabolism  contributes to
# 14                              normal muscle function  contributes to
# 15                            normal neurotransmission  contributes to
# 16            the normal function of digestive enzymes  contributes to
# 17     the process of cell division and specialisation   has a role in
# 18                     the maintenance of normal bones      needed for
# 19                     the maintenance of normal teeth      needed for
# 20   the maintenance of endurance performance durin...   contribute to
# 21    the absorption of water during physical exercise         enhance
# 22            the maintenance of normal brain function   contribute to
# 23   the maintenance of normal blood cholesterol le...  contributes to
# 24   normal digestion by production of hydrochloric...  contributes to
# 25                      normal homocysteine metabolism  contributes to
# 26                             normal lipid metabolism  contributes to
# 27            the maintenance of normal liver function  contributes to
# 28                     normal macronutrient metabolism  contributes to
# 29      the maintenance of normal blood glucose levels  contributes to
# ..                                                 ...             ...
# 231                      sugar-containing foods/drinks     compared to
# 232            the maintenance of tooth mineralisation  contributes to
# 233  the effect of resistance training on muscle st...         enhance
# 234  normal bowel function by increasing stool freq...  contributes to
# 235               an&nbsp;increase in&nbsp;faecal bulk  contributes to
# 236  reduce the loss of bone mineral in post-menopa...         help to
# 237  reduce the loss of bone mineral in post-menopa...        helps to
# 238  reduce the risk of falling associated with pos...        helps to
# 239  lower/reduce blood cholesterol high cholestero...        shown to
# 240  maternal folate status low maternal folate sta...       increases
# 241  lower/reduce blood cholesterol high cholestero...        shown to
# 242  reduce dental plaque high content/level of den...        shown to
# 243  lower/reduce blood cholesterol high cholestero...        shown to
# 244  lower/reduce blood cholesterol high cholestero...        shown to
# 245  lower/reduce blood cholesterol high cholestero...        shown to
# 246  lower/reduce blood cholesterol high cholestero...        shown to
# 247  neutralise plaque acids plaque acids are a ris...           helps
# 248  reduce tooth demineralisation tooth deminerali...           helps
# 249  normal growth and development of bone in children      needed for
# 250  normal growth and development of bone in children      needed for
# 251        the normal visual development of infants up  contributes to
# 252  the normal brain development of the foetus and...  contributes to
# 253  the normal development of the eye of the foetu...  contributes to
# 254          normal growth and development of children      needed for
# 255                      the normal growth of children  contributes to
# 256           normal cognitive development of children  contributes to
# 257  the normal growth and development of bone in c...      needed for
# 258  normal growth and development of bone in children      needed for
# 259  the normal function of the immune system in ch...  contributes to
# 260  normal growth and development of bone in children      needed for
#
# [261 rows x 9 columns]

# %%
benefits = df_hc_res.benefit.unique()
pd.Series(benefits).to_csv('benefits.csv',index=None)

# %%
df_hc_res.to_csv('hc_approval.csv',index=None)

# %%
phrases = df_hc_res.phrase.unique()
pd.Series(phrases).to_csv('phrases.csv',index=None)

# %%
# Get the unique benefit and phrase

phrases = [[ps.stem(word) for word in word_tokenize(p)] for p in phrases]
